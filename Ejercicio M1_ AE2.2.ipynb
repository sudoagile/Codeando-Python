# %% [markdown]
# 1. Escriba una función que muestre por pantalla el resultado de multiplicar un número por 10.

# %%
def resultado(numero):
  calculo= (numero*10)
  return calculo

# %%
resultado (int(input("Ingrese un número:")))
# Out:
# 60

# %% [markdown]
# 2. Escriba función que devuelva si el número es par (true) o impar (false).

# %%
def paridad(numero):
  if numero % 2 == 0:
    print (True)

  else:

    print (False)

paridad (int(input("Ingrese un número:")))
# Out:
# True

# %% [markdown]
# 3. Escriba un programa que pida dos años y escriba cuántos años bisiestos hay entre esas dos fechas (incluidos los dos años):

# %%
año1 = int(input("Año 1:"))
año2 = int(input("Año 2:"))


años = list (range(año1, año2+1))
contador = 0
for i in años:
  if i % 4 == 0 and (i % 100 != 0 or i % 400 == 0):
    contador += 1
    print (i,"Es bisiesto")

print("Existen: ", contador , " años biciestos")

#if año % 4 == 0 and (año % 100 != 0 or año % 400 == 0):
#	print("Es bisiesto")
#else:
#	print("No es bisiesto")
# Out:
# Año 1:1980
# Año 2:2022
# 1980 Es bisiesto
# 1984 Es bisiesto
# 1988 Es bisiesto
# 1992 Es bisiesto
# 1996 Es bisiesto
# 2000 Es bisiesto
# 2004 Es bisiesto
# 2008 Es bisiesto
# 2012 Es bisiesto
# 2016 Es bisiesto
# 2020 Es bisiesto
# Existen:  11  años biciestos

# %% [markdown]
# 4. Desarrolle un programa que pida la anchura y altura de un rectángulo y lo dibuje con caracteres producto (*)

# %%
anchura = int(input("Anchura: "))
altura = int(input("Altura: "))

#figura = list(range(anchura))

for i in range(altura):

  for j in range(anchura):

    print("* ", end="")
  print()
# Out:
# * * * * * * * * * *
# * * * * * * * * * *
# * * * * * * * * * *

# %% [markdown]
# 5. Escribir una función sum() y una función () que sumen y multipliquen respectivamnete todos los número de una lista. Por ejemplo: sum([1,2,3,4]) debería devolver 10 y multip([1,2,3,4]) debería devolver 24.

# %%
def suma(a):
    total = 0
    for i in range(len(a)):
        total += a[i] 
    return total
def mult(a):
    total = 1
    for i in range(len(a)):
        total *= a[i]
    return total

print(suma([1,2,3,4]))
print(mult([1,2,3,4]))
# Out:
# 10
# 24

# %% [markdown]
# 6.	Escribir un pequeño programa donde:
# ●	Se ingresa el año en curso.
# ●	Se ingresa el nombre y el año de nacimiento de tres personas.
# ●	Se calcula cuántos años cumplirán durante el año en curso.
# ●	Se imprime en pantalla.

# %%
ano_actual = int(input ("Ingresa el año en curso: "))
for i  in range (3):
        nombre = input ("Ingrese nombre: ")
        ano_nacimiento = int(input ("Anio de nacimiento: "))
        ano_cumpleano = (ano_actual - ano_nacimiento)
        print(f'{nombre} cumple {ano_cumpleano} años en el {ano_actual}')
# Out:
# Eduardo cumple 52 años en el 2022
# Luis cumple 51 años en el 2022
# Aurora cumple 46 años en el 2022

# %% [markdown]
# 7.	Crear una función que tome una lista de dígitos y devuelva al número al que corresponden. Por ejemplo [1,2,3] corresponde a el número ciento veintitrés (123). (Puede utilizar la función reduce()).

# %%
from functools import reduce

def digitos_a_numero(digitos):
    return reduce(lambda x,y:x*10 + y,digitos)
digitos_a_numero([1,2,3])
# Out:
# 123
